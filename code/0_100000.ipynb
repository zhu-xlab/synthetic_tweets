# %%
import json
import pandas as pd
import os
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import shape, Polygon, MultiPolygon
from shapely.wkt import loads
import requests

# %%
print(os.getpid())
# Out:
# 23122
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df = pd.read_csv("/mntssd/mnt3/shanshanbai/nlpinearthobservation/synthetic_data/merged.csv", sep=",")
df = df.iloc[22507:100000]
df['geometry'] = df['geometry'].apply(loads)

# %%
len(df)

# %%
df.head()

# %%
# Output JSON Lines file to save results dynamically
output_file = "/mntssd/mnt3/shanshanbai/my_storage_from_qian/results/0_100000.jsonl"

# %%
# Define Overpass API endpoint
url = "https://overpass-api.de/api/interpreter"

# %%
# Function to decode Unicode escape sequences
def decode_unicode(string):
    try:
        return json.loads(f'"{string}"')  # Decodes strings like "\u00fc" to "ü"
    except json.JSONDecodeError:
        return string  # Return the string as-is if decoding fails

# Function to extract building information
def extract_building_info(element):
    tags = element.get('tags', {})
    building_type = tags.get('building')
    name = tags.get('name')
    operator = tags.get('operator')

    # Decode Unicode sequences in strings
    if name:
        name = decode_unicode(name)
    if operator:
        operator = decode_unicode(operator)
    
    return building_type, name, operator

# %%
# Process each geometry in the DataFrame
for index, row in df.iterrows():
    geometry = row['geometry']
    bounds = geometry.bounds  # (minx, miny, maxx, maxy)
    south, west, north, east = bounds[1], bounds[0], bounds[3], bounds[2]

    # Overpass query to retrieve relations, ways, and nodes
    query = f"""
    [out:json];
    (
      way["building"]({south},{west},{north},{east});
      relation["building"]({south},{west},{north},{east});
      node["building"]({south},{west},{north},{east});
    );
    out body;
    >;
    out skel qt;
    """
    
    # Initialize combined data for the current geometry
    combined_data = {
        'index': index,
        'building id': row.get("osm_building_id", None),
        'building class': row.get("building_class", None),
        'building city': row.get("building_city", None),
        'building tags': set(),
        'building names': set(),
        'building operators': set(),
        'tweet language distribution': row.get("tweet_lang", None),  # Include additional column if available
        'error': None  # Track errors if they occur
    }

    # Query the Overpass API
    try:
        response = requests.get(url, params={"data": query})
        response.raise_for_status()
        data = response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error querying Overpass API for geometry {index}: {e}")
        combined_data['error'] = f"HTTP error: {str(e)}"
        # Write the error result for this row
        with open(output_file, "a", encoding="utf-8") as f:
            # json.dump(combined_data, f, ensure_ascii=False)
            f.write("Error querying Overpass API")
            f.write("\n")
        continue  # Skip processing this row

    # Check if data is empty
    if not data.get("elements"):
        print(f"No data retrieved for geometry {index}")
        combined_data['error'] = "No data retrieved from Overpass API"
        # Write the empty result for this row
        with open(output_file, "a", encoding="utf-8") as f:
            # json.dump(combined_data, f, ensure_ascii=False)
            f.write("No data retrieved from Overpass API")
            f.write("\n")
        continue

    # Process elements from the response
    for element in data.get("elements", []):
        if element["type"] in ["relation", "way"]:
            building_type, name, operator = extract_building_info(element)
            if building_type and building_type != "yes":
                combined_data["building tags"].add(building_type)
            if name:
                combined_data["building names"].add(name)
            if operator:
                combined_data["building operators"].add(operator)

    # Convert sets to lists for JSON compatibility
    combined_data["building tags"] = list(combined_data["building tags"])
    combined_data["building names"] = list(combined_data["building names"])
    combined_data["building operators"] = list(combined_data["building operators"])

    # Use fallback from 'building_class' if 'building tags' is empty
    if not combined_data['building tags']:
        fallback_class = row.get("building_class", None)
        if pd.notna(fallback_class):
            combined_data['building tags'].append(fallback_class)

    # Save results dynamically to JSON Lines file
    with open(output_file, "a", encoding="utf-8") as f:
        json.dump(combined_data, f, ensure_ascii=False)
        f.write("\n")

    print(f"Saved results for geometry {index}/{len(df)}")
# Out:
# Saved results for geometry 22507/77493
# Saved results for geometry 22508/77493
# Saved results for geometry 22509/77493
# Saved results for geometry 22510/77493
# Saved results for geometry 22511/77493
# Saved results for geometry 22512/77493
# Saved results for geometry 22513/77493
# Saved results for geometry 22514/77493
# Saved results for geometry 22515/77493
# Saved results for geometry 22516/77493
# Saved results for geometry 22517/77493
# Saved results for geometry 22518/77493
# Saved results for geometry 22519/77493
# Saved results for geometry 22520/77493
# Saved results for geometry 22521/77493
# Saved results for geometry 22522/77493
# Saved results for geometry 22523/77493
# Saved results for geometry 22524/77493
# Saved results for geometry 22525/77493
# Saved results for geometry 22526/77493
# Saved results for geometry 22527/77493
# Saved results for geometry 22528/77493
# Saved results for geometry 22529/77493
# Saved results for geometry 22530/77493
# Saved results for geometry 22531/77493
# Saved results for geometry 22532/77493
# Saved results for geometry 22533/77493
# Saved results for geometry 22534/77493
# Saved results for geometry 22535/77493
# Saved results for geometry 22536/77493
# Saved results for geometry 22537/77493
# Saved results for geometry 22538/77493
# Saved results for geometry 22539/77493
# Saved results for geometry 22540/77493
# Saved results for geometry 22541/77493
# Saved results for geometry 22542/77493
# Saved results for geometry 22543/77493
# Saved results for geometry 22544/77493
# Saved results for geometry 22545/77493
# Saved results for geometry 22546/77493
# Saved results for geometry 22547/77493
# Saved results for geometry 22548/77493
# Saved results for geometry 22549/77493
# Saved results for geometry 22550/77493
# Saved results for geometry 22551/77493
# Saved results for geometry 22552/77493
# Saved results for geometry 22553/77493
# Saved results for geometry 22554/77493
# Saved results for geometry 22555/77493
# Saved results for geometry 22556/77493
# Saved results for geometry 22557/77493
# Saved results for geometry 22558/77493
# Saved results for geometry 22559/77493
# Saved results for geometry 22560/77493
# Saved results for geometry 22561/77493
# Saved results for geometry 22562/77493
# Saved results for geometry 22563/77493
# Saved results for geometry 22564/77493
# Saved results for geometry 22565/77493
# Saved results for geometry 22566/77493
# Saved results for geometry 22567/77493
# Saved results for geometry 22568/77493
# Saved results for geometry 22569/77493
# Saved results for geometry 22570/77493
# Saved results for geometry 22571/77493
# Saved results for geometry 22572/77493
# Saved results for geometry 22573/77493
# Saved results for geometry 22574/77493
# Saved results for geometry 22575/77493
# Saved results for geometry 22576/77493
# Saved results for geometry 22577/77493
# Saved results for geometry 22578/77493
# Saved results for geometry 22579/77493
# Saved results for geometry 22580/77493
# Saved results for geometry 22581/77493
# Saved results for geometry 22582/77493
# Saved results for geometry 22583/77493
# Saved results for geometry 22584/77493
# Saved results for geometry 22585/77493
# Saved results for geometry 22586/77493
# Saved results for geometry 22587/77493
# Saved results for geometry 22588/77493
# Saved results for geometry 22589/77493
# Saved results for geometry 22590/77493
# Saved results for geometry 22591/77493
# Saved results for geometry 22592/77493
# Saved results for geometry 22593/77493
# Saved results for geometry 22594/77493
# Saved results for geometry 22595/77493
# Saved results for geometry 22596/77493
# Saved results for geometry 22597/77493
# Saved results for geometry 22598/77493
# Saved results for geometry 22599/77493
# Saved results for geometry 22600/77493
# Saved results for geometry 22601/77493
# Saved results for geometry 22602/77493
# No data retrieved for geometry 22603
# Saved results for geometry 22604/77493
# Saved results for geometry 22605/77493
# Saved results for geometry 22606/77493
# Saved results for geometry 22607/77493
# Saved results for geometry 22608/77493
# Saved results for geometry 22609/77493
# Saved results for geometry 22610/77493
# Saved results for geometry 22611/77493
# Saved results for geometry 22612/77493
# Saved results for geometry 22613/77493
# Saved results for geometry 22614/77493
# Saved results for geometry 22615/77493
# Saved results for geometry 22616/77493
# Saved results for geometry 22617/77493
# Saved results for geometry 22618/77493
# Saved results for geometry 22619/77493
# Saved results for geometry 22620/77493
# Saved results for geometry 22621/77493
# Saved results for geometry 22622/77493
# Saved results for geometry 22623/77493
# Saved results for geometry 22624/77493
# Saved results for geometry 22625/77493
# Saved results for geometry 22626/77493
# Saved results for geometry 22627/77493
# Saved results for geometry 22628/77493
# Saved results for geometry 22629/77493
# Saved results for geometry 22630/77493
# Saved results for geometry 22631/77493
# Saved results for geometry 22632/77493
# Saved results for geometry 22633/77493
# Saved results for geometry 22634/77493
# Saved results for geometry 22635/77493
# Saved results for geometry 22636/77493
# Saved results for geometry 22637/77493
# Saved results for geometry 22638/77493
# Saved results for geometry 22639/77493
# Saved results for geometry 22640/77493
# Saved results for geometry 22641/77493
# Saved results for geometry 22642/77493
# Saved results for geometry 22643/77493
# Saved results for geometry 22644/77493
# Saved results for geometry 22645/77493
# Saved results for geometry 22646/77493
# Saved results for geometry 22647/77493
# Saved results for geometry 22648/77493
# Saved results for geometry 22649/77493
# Saved results for geometry 22650/77493
# Saved results for geometry 22651/77493
# Saved results for geometry 22652/77493
# Saved results for geometry 22653/77493
# Saved results for geometry 22654/77493
# Saved results for geometry 22655/77493
# Saved results for geometry 22656/77493
# Saved results for geometry 22657/77493
# Saved results for geometry 22658/77493
# Saved results for geometry 22659/77493
# Saved results for geometry 22660/77493
# Saved results for geometry 22661/77493
# Saved results for geometry 22662/77493
# Saved results for geometry 22663/77493
# Saved results for geometry 22664/77493
# Saved results for geometry 22665/77493
# Saved results for geometry 22666/77493
# Saved results for geometry 22667/77493
# Saved results for geometry 22668/77493
# Saved results for geometry 22669/77493
# Saved results for geometry 22670/77493
# Saved results for geometry 22671/77493
# Saved results for geometry 22672/77493
# Saved results for geometry 22673/77493
# Saved results for geometry 22674/77493
# Saved results for geometry 22675/77493
# Saved results for geometry 22676/77493
# Saved results for geometry 22677/77493
# Saved results for geometry 22678/77493
# Saved results for geometry 22679/77493
# Saved results for geometry 22680/77493
# Saved results for geometry 22681/77493
# Saved results for geometry 22682/77493
# Saved results for geometry 22683/77493
# Saved results for geometry 22684/77493
# Saved results for geometry 22685/77493
# Saved results for geometry 22686/77493
# Saved results for geometry 22687/77493
# Saved results for geometry 22688/77493
# Saved results for geometry 22689/77493
# Saved results for geometry 22690/77493
# Saved results for geometry 22691/77493
# Saved results for geometry 22692/77493
# Saved results for geometry 22693/77493
# Saved results for geometry 22694/77493
# Saved results for geometry 22695/77493
# Saved results for geometry 22696/77493
# Saved results for geometry 22697/77493
# Saved results for geometry 22698/77493
# Saved results for geometry 22699/77493
# Saved results for geometry 22700/77493
# Saved results for geometry 22701/77493
# Saved results for geometry 22702/77493
# Saved results for geometry 22703/77493
# Saved results for geometry 22704/77493
# Saved results for geometry 22705/77493
# Saved results for geometry 22706/77493
# Saved results for geometry 22707/77493
# Saved results for geometry 22708/77493
# Saved results for geometry 22709/77493
# Saved results for geometry 22710/77493
# Saved results for geometry 22711/77493
# No data retrieved for geometry 22712
# Saved results for geometry 22713/77493
# Saved results for geometry 22714/77493
# Saved results for geometry 22715/77493
# Saved results for geometry 22716/77493
# Saved results for geometry 22717/77493
# Saved results for geometry 22718/77493
# Saved results for geometry 22719/77493
# Saved results for geometry 22720/77493
# Saved results for geometry 22721/77493
# Saved results for geometry 22722/77493
# Saved results for geometry 22723/77493
# Saved results for geometry 22724/77493
# Saved results for geometry 22725/77493
# Saved results for geometry 22726/77493
# Saved results for geometry 22727/77493
# Saved results for geometry 22728/77493
# Saved results for geometry 22729/77493
# Saved results for geometry 22730/77493
# Saved results for geometry 22731/77493
# Saved results for geometry 22732/77493
# Saved results for geometry 22733/77493
# Saved results for geometry 22734/77493
# Saved results for geometry 22735/77493
# Saved results for geometry 22736/77493
# Saved results for geometry 22737/77493
# Saved results for geometry 22738/77493
# Saved results for geometry 22739/77493
# Saved results for geometry 22740/77493
# Saved results for geometry 22741/77493
# Saved results for geometry 22742/77493
# Saved results for geometry 22743/77493
# Saved results for geometry 22744/77493
# Saved results for geometry 22745/77493
# Saved results for geometry 22746/77493
# Saved results for geometry 22747/77493
# Saved results for geometry 22748/77493
# Saved results for geometry 22749/77493
# Saved results for geometry 22750/77493
# Saved results for geometry 22751/77493
# Saved results for geometry 22752/77493
# Saved results for geometry 22753/77493
# Saved results for geometry 22754/77493
# Saved results for geometry 22755/77493
# Saved results for geometry 22756/77493
# Saved results for geometry 22757/77493
# Saved results for geometry 22758/77493
# Saved results for geometry 22759/77493
# Saved results for geometry 22760/77493
# Saved results for geometry 22761/77493
# Saved results for geometry 22762/77493
# Saved results for geometry 22763/77493
# Saved results for geometry 22764/77493
# Saved results for geometry 22765/77493
# Saved results for geometry 22766/77493
# Saved results for geometry 22767/77493
# Saved results for geometry 22768/77493
# Saved results for geometry 22769/77493
# Saved results for geometry 22770/77493
# Saved results for geometry 22771/77493
# Saved results for geometry 22772/77493
# Saved results for geometry 22773/77493
# Saved results for geometry 22774/77493
# Saved results for geometry 22775/77493
# Saved results for geometry 22776/77493
# Saved results for geometry 22777/77493
# Saved results for geometry 22778/77493
# Saved results for geometry 22779/77493
# Saved results for geometry 22780/77493
# Saved results for geometry 22781/77493
# Saved results for geometry 22782/77493
# Saved results for geometry 22783/77493
# Saved results for geometry 22784/77493
# Saved results for geometry 22785/77493
# Saved results for geometry 22786/77493
# Saved results for geometry 22787/77493
# Saved results for geometry 22788/77493
# Saved results for geometry 22789/77493
# Saved results for geometry 22790/77493
# Saved results for geometry 22791/77493
# Saved results for geometry 22792/77493
# Saved results for geometry 22793/77493
# Saved results for geometry 22794/77493
# Saved results for geometry 22795/77493
# Saved results for geometry 22796/77493
# Saved results for geometry 22797/77493
# Saved results for geometry 22798/77493
# Saved results for geometry 22799/77493
# Saved results for geometry 22800/77493
# Saved results for geometry 22801/77493
# Saved results for geometry 22802/77493
# Saved results for geometry 22803/77493
# Saved results for geometry 22804/77493
# Saved results for geometry 22805/77493
# Saved results for geometry 22806/77493
# Saved results for geometry 22807/77493
# Saved results for geometry 22808/77493
# Saved results for geometry 22809/77493
# Saved results for geometry 22810/77493
# Saved results for geometry 22811/77493
# Saved results for geometry 22812/77493
# Saved results for geometry 22813/77493
# Saved results for geometry 22814/77493
# Saved results for geometry 22815/77493
# Saved results for geometry 22816/77493
# Saved results for geometry 22817/77493
# Saved results for geometry 22818/77493
# Saved results for geometry 22819/77493
# Saved results for geometry 22820/77493
# Saved results for geometry 22821/77493
# Saved results for geometry 22822/77493
# Saved results for geometry 22823/77493
# Saved results for geometry 22824/77493
# Saved results for geometry 22825/77493
# Saved results for geometry 22826/77493
# Saved results for geometry 22827/77493
# Saved results for geometry 22828/77493
# Saved results for geometry 22829/77493
# Saved results for geometry 22830/77493
# Saved results for geometry 22831/77493
# Saved results for geometry 22832/77493
# Saved results for geometry 22833/77493
# Saved results for geometry 22834/77493
# Saved results for geometry 22835/77493
# Saved results for geometry 22836/77493
# Saved results for geometry 22837/77493
# Saved results for geometry 22838/77493
# Saved results for geometry 22839/77493
# Saved results for geometry 22840/77493
# Saved results for geometry 22841/77493
# Saved results for geometry 22842/77493
# Saved results for geometry 22843/77493
# Saved results for geometry 22844/77493
# Saved results for geometry 22845/77493
# Saved results for geometry 22846/77493
# Saved results for geometry 22847/77493
# Saved results for geometry 22848/77493
# Saved results for geometry 22849/77493
# Saved results for geometry 22850/77493
# Saved results for geometry 22851/77493
# Saved results for geometry 22852/77493
# Saved results for geometry 22853/77493
# Saved results for geometry 22854/77493
# Saved results for geometry 22855/77493
# Saved results for geometry 22856/77493
# Saved results for geometry 22857/77493
# Saved results for geometry 22858/77493
# Saved results for geometry 22859/77493
# Saved results for geometry 22860/77493
# Saved results for geometry 22861/77493
# Saved results for geometry 22862/77493
# Saved results for geometry 22863/77493
# Saved results for geometry 22864/77493
# Saved results for geometry 22865/77493
# Saved results for geometry 22866/77493
# Saved results for geometry 22867/77493
# Saved results for geometry 22868/77493
# Saved results for geometry 22869/77493
# Saved results for geometry 22870/77493
# Saved results for geometry 22871/77493
# Saved results for geometry 22872/77493
# Saved results for geometry 22873/77493
# Saved results for geometry 22874/77493
# Saved results for geometry 22875/77493
# Saved results for geometry 22876/77493
# Saved results for geometry 22877/77493
# Saved results for geometry 22878/77493
# Saved results for geometry 22879/77493
# Saved results for geometry 22880/77493
# Saved results for geometry 22881/77493
# Saved results for geometry 22882/77493
# Saved results for geometry 22883/77493
# Saved results for geometry 22884/77493
# Saved results for geometry 22885/77493
# Saved results for geometry 22886/77493
# Saved results for geometry 22887/77493
# Saved results for geometry 22888/77493
# Saved results for geometry 22889/77493
# Saved results for geometry 22890/77493
# Saved results for geometry 22891/77493
# Saved results for geometry 22892/77493
# Saved results for geometry 22893/77493
# Saved results for geometry 22894/77493
# Saved results for geometry 22895/77493
# Saved results for geometry 22896/77493
# Saved results for geometry 22897/77493
# Saved results for geometry 22898/77493
# Saved results for geometry 22899/77493
# Saved results for geometry 22900/77493
# Saved results for geometry 22901/77493
# Saved results for geometry 22902/77493
# Saved results for geometry 22903/77493
# Saved results for geometry 22904/77493
# Saved results for geometry 22905/77493
# Saved results for geometry 22906/77493
# Saved results for geometry 22907/77493
# No data retrieved for geometry 22908
# Saved results for geometry 22909/77493
# Saved results for geometry 22910/77493
# Saved results for geometry 22911/77493
# Saved results for geometry 22912/77493
# Saved results for geometry 22913/77493
# Saved results for geometry 22914/77493
# Saved results for geometry 22915/77493
# Saved results for geometry 22916/77493
# Saved results for geometry 22917/77493
# Saved results for geometry 22918/77493
# Saved results for geometry 22919/77493
# Saved results for geometry 22920/77493
# Saved results for geometry 22921/77493
# Saved results for geometry 22922/77493
# Saved results for geometry 22923/77493
# Saved results for geometry 22924/77493
# Saved results for geometry 22925/77493
# Saved results for geometry 22926/77493
# Saved results for geometry 22927/77493
# Saved results for geometry 22928/77493
# Saved results for geometry 22929/77493
# Saved results for geometry 22930/77493
# Saved results for geometry 22931/77493
# No data retrieved for geometry 22932
# Saved results for geometry 22933/77493
# Saved results for geometry 22934/77493
# Saved results for geometry 22935/77493
# Saved results for geometry 22936/77493
# Saved results for geometry 22937/77493
# Saved results for geometry 22938/77493
# Saved results for geometry 22939/77493
# Saved results for geometry 22940/77493
# Saved results for geometry 22941/77493
# Saved results for geometry 22942/77493
# Saved results for geometry 22943/77493
# Saved results for geometry 22944/77493
# Saved results for geometry 22945/77493
# Saved results for geometry 22946/77493
# Saved results for geometry 22947/77493
# Saved results for geometry 22948/77493
# Saved results for geometry 22949/77493
# Saved results for geometry 22950/77493
# Saved results for geometry 22951/77493
# Saved results for geometry 22952/77493
# Saved results for geometry 22953/77493
# Saved results for geometry 22954/77493
# Saved results for geometry 22955/77493
# Saved results for geometry 22956/77493
# Saved results for geometry 22957/77493
# Saved results for geometry 22958/77493
# Saved results for geometry 22959/77493
# Saved results for geometry 22960/77493
# Saved results for geometry 22961/77493
# Saved results for geometry 22962/77493
# Saved results for geometry 22963/77493
# Saved results for geometry 22964/77493
# Saved results for geometry 22965/77493
# Saved results for geometry 22966/77493
# Saved results for geometry 22967/77493
# Saved results for geometry 22968/77493
# Saved results for geometry 22969/77493
# Saved results for geometry 22970/77493
# Saved results for geometry 22971/77493
# Saved results for geometry 22972/77493
# Saved results for geometry 22973/77493
# Saved results for geometry 22974/77493
# Saved results for geometry 22975/77493
# Saved results for geometry 22976/77493
# Saved results for geometry 22977/77493
# Saved results for geometry 22978/77493
# Saved results for geometry 22979/77493
# Saved results for geometry 22980/77493
# Saved results for geometry 22981/77493
# Saved results for geometry 22982/77493
# Saved results for geometry 22983/77493
# Saved results for geometry 22984/77493
# Saved results for geometry 22985/77493
# Saved results for geometry 22986/77493
# Saved results for geometry 22987/77493
# Saved results for geometry 22988/77493
# Saved results for geometry 22989/77493
# Saved results for geometry 22990/77493
# Saved results for geometry 22991/77493
# Saved results for geometry 22992/77493
# Saved results for geometry 22993/77493
# Saved results for geometry 22994/77493
# Saved results for geometry 22995/77493
# Saved results for geometry 22996/77493
# Saved results for geometry 22997/77493
# Saved results for geometry 22998/77493
# Saved results for geometry 22999/77493
# Saved results for geometry 23000/77493
# Saved results for geometry 23001/77493
# Saved results for geometry 23002/77493
# Saved results for geometry 23003/77493
# Saved results for geometry 23004/77493
# Saved results for geometry 23005/77493
# Saved results for geometry 23006/77493
# Saved results for geometry 23007/77493
# Saved results for geometry 23008/77493
# Saved results for geometry 23009/77493
# Saved results for geometry 23010/77493
# Saved results for geometry 23011/77493
# Saved results for geometry 23012/77493
# Saved results for geometry 23013/77493
# Saved results for geometry 23014/77493
# Saved results for geometry 23015/77493
# Saved results for geometry 23016/77493
# Saved results for geometry 23017/77493
# Saved results for geometry 23018/77493
# Saved results for geometry 23019/77493
# Saved results for geometry 23020/77493
# Saved results for geometry 23021/77493
# Saved results for geometry 23022/77493
# Saved results for geometry 23023/77493
# Saved results for geometry 23024/77493
# Saved results for geometry 23025/77493
# Saved results for geometry 23026/77493
# Saved results for geometry 23027/77493
# Saved results for geometry 23028/77493
# Saved results for geometry 23029/77493
# Saved results for geometry 23030/77493
# Saved results for geometry 23031/77493
# Saved results for geometry 23032/77493
# Saved results for geometry 23033/77493
# Saved results for geometry 23034/77493
# Saved results for geometry 23035/77493
# Saved results for geometry 23036/77493
# Saved results for geometry 23037/77493
# Saved results for geometry 23038/77493
# Saved results for geometry 23039/77493
# Saved results for geometry 23040/77493
# Saved results for geometry 23041/77493
# Saved results for geometry 23042/77493
# Saved results for geometry 23043/77493
# Saved results for geometry 23044/77493
# Saved results for geometry 23045/77493
# Saved results for geometry 23046/77493
# Saved results for geometry 23047/77493
# Saved results for geometry 23048/77493
# Saved results for geometry 23049/77493
# Saved results for geometry 23050/77493
# Saved results for geometry 23051/77493
# Saved results for geometry 23052/77493
# Saved results for geometry 23053/77493
# Saved results for geometry 23054/77493
# Saved results for geometry 23055/77493
# Saved results for geometry 23056/77493
# Saved results for geometry 23057/77493
# Saved results for geometry 23058/77493
# Saved results for geometry 23059/77493
# Saved results for geometry 23060/77493
# Saved results for geometry 23061/77493
# Saved results for geometry 23062/77493
# Saved results for geometry 23063/77493
# Saved results for geometry 23064/77493
# Saved results for geometry 23065/77493
# Saved results for geometry 23066/77493
# Saved results for geometry 23067/77493
# Saved results for geometry 23068/77493
# Saved results for geometry 23069/77493
# Saved results for geometry 23070/77493
# Saved results for geometry 23071/77493
# Saved results for geometry 23072/77493
# Saved results for geometry 23073/77493
# Saved results for geometry 23074/77493
# Saved results for geometry 23075/77493
# Saved results for geometry 23076/77493
# Saved results for geometry 23077/77493
# Saved results for geometry 23078/77493
# Saved results for geometry 23079/77493
# Saved results for geometry 23080/77493
# Saved results for geometry 23081/77493
# Saved results for geometry 23082/77493
# Saved results for geometry 23083/77493
# Saved results for geometry 23084/77493
# Saved results for geometry 23085/77493
# Saved results for geometry 23086/77493
# Saved results for geometry 23087/77493
# Saved results for geometry 23088/77493
# Saved results for geometry 23089/77493
# Saved results for geometry 23090/77493
# Saved results for geometry 23091/77493
# Saved results for geometry 23092/77493
# Saved results for geometry 23093/77493
# Saved results for geometry 23094/77493
# Saved results for geometry 23095/77493
# Saved results for geometry 23096/77493
# Saved results for geometry 23097/77493
# Saved results for geometry 23098/77493
# Saved results for geometry 23099/77493
# Saved results for geometry 23100/77493
# Saved results for geometry 23101/77493
# Saved results for geometry 23102/77493
# Saved results for geometry 23103/77493
# Saved results for geometry 23104/77493
# Saved results for geometry 23105/77493
# Saved results for geometry 23106/77493
# Saved results for geometry 23107/77493
# Saved results for geometry 23108/77493
# Saved results for geometry 23109/77493
# Saved results for geometry 23110/77493
# Saved results for geometry 23111/77493
# Saved results for geometry 23112/77493
# Saved results for geometry 23113/77493
# Saved results for geometry 23114/77493
# Saved results for geometry 23115/77493
# Saved results for geometry 23116/77493
# Saved results for geometry 23117/77493
# Saved results for geometry 23118/77493
# Saved results for geometry 23119/77493
# Saved results for geometry 23120/77493
# Saved results for geometry 23121/77493
# Saved results for geometry 23122/77493
# Saved results for geometry 23123/77493
# Saved results for geometry 23124/77493
# Saved results for geometry 23125/77493
# Saved results for geometry 23126/77493
# Saved results for geometry 23127/77493
# Saved results for geometry 23128/77493
# Saved results for geometry 23129/77493
# Saved results for geometry 23130/77493
# Saved results for geometry 23131/77493
# Saved results for geometry 23132/77493
# Saved results for geometry 23133/77493
# Saved results for geometry 23134/77493
# Saved results for geometry 23135/77493
# Saved results for geometry 23136/77493
# Saved results for geometry 23137/77493
# Saved results for geometry 23138/77493
# Saved results for geometry 23139/77493
# Saved results for geometry 23140/77493
# Saved results for geometry 23141/77493
# Saved results for geometry 23142/77493
# Saved results for geometry 23143/77493
# Saved results for geometry 23144/77493
# Saved results for geometry 23145/77493
# Saved results for geometry 23146/77493
# Saved results for geometry 23147/77493
# Saved results for geometry 23148/77493
# Saved results for geometry 23149/77493
# Saved results for geometry 23150/77493
# Saved results for geometry 23151/77493
# Saved results for geometry 23152/77493
# Saved results for geometry 23153/77493
# Saved results for geometry 23154/77493
# Saved results for geometry 23155/77493
# Saved results for geometry 23156/77493
# Saved results for geometry 23157/77493
# Saved results for geometry 23158/77493
# Saved results for geometry 23159/77493
# Saved results for geometry 23160/77493
# Saved results for geometry 23161/77493
# Saved results for geometry 23162/77493
# Saved results for geometry 23163/77493
# Saved results for geometry 23164/77493
# Saved results for geometry 23165/77493
# Saved results for geometry 23166/77493
# Saved results for geometry 23167/77493
# Saved results for geometry 23168/77493
# Saved results for geometry 23169/77493
# Saved results for geometry 23170/77493
# Saved results for geometry 23171/77493
# Saved results for geometry 23172/77493
# Saved results for geometry 23173/77493
# Saved results for geometry 23174/77493
# Saved results for geometry 23175/77493
# Saved results for geometry 23176/77493
# Saved results for geometry 23177/77493
# Saved results for geometry 23178/77493
# Saved results for geometry 23179/77493
# Saved results for geometry 23180/77493
# Saved results for geometry 23181/77493
# Saved results for geometry 23182/77493
# Saved results for geometry 23183/77493
# Saved results for geometry 23184/77493
# Saved results for geometry 23185/77493
# Saved results for geometry 23186/77493
# Saved results for geometry 23187/77493
# Saved results for geometry 23188/77493
# Saved results for geometry 23189/77493
# Saved results for geometry 23190/77493
# Saved results for geometry 23191/77493
# Saved results for geometry 23192/77493
# Saved results for geometry 23193/77493
# Saved results for geometry 23194/77493
# Saved results for geometry 23195/77493
# Saved results for geometry 23196/77493
# Saved results for geometry 23197/77493
# Saved results for geometry 23198/77493
# Saved results for geometry 23199/77493
# Saved results for geometry 23200/77493
# Saved results for geometry 23201/77493
# Saved results for geometry 23202/77493
# Saved results for geometry 23203/77493
# Saved results for geometry 23204/77493
# Saved results for geometry 23205/77493
# Saved results for geometry 23206/77493
# Saved results for geometry 23207/77493
# Saved results for geometry 23208/77493
# Saved results for geometry 23209/77493
# Saved results for geometry 23210/77493
# Saved results for geometry 23211/77493
# Saved results for geometry 23212/77493
# Saved results for geometry 23213/77493
# Saved results for geometry 23214/77493
# Saved results for geometry 23215/77493
# Saved results for geometry 23216/77493
# Saved results for geometry 23217/77493
# Saved results for geometry 23218/77493
# Saved results for geometry 23219/77493
# Saved results for geometry 23220/77493
# Saved results for geometry 23221/77493
# Saved results for geometry 23222/77493
# Saved results for geometry 23223/77493
# Saved results for geometry 23224/77493
# Saved results for geometry 23225/77493
# Saved results for geometry 23226/77493
# Saved results for geometry 23227/77493
# Saved results for geometry 23228/77493
# Saved results for geometry 23229/77493
# Saved results for geometry 23230/77493
# Saved results for geometry 23231/77493
# Saved results for geometry 23232/77493
# Saved results for geometry 23233/77493
# Saved results for geometry 23234/77493
# Saved results for geometry 23235/77493
# Saved results for geometry 23236/77493
# Saved results for geometry 23237/77493
# Saved results for geometry 23238/77493
# Saved results for geometry 23239/77493
# Saved results for geometry 23240/77493
# Saved results for geometry 23241/77493
# Saved results for geometry 23242/77493
# Saved results for geometry 23243/77493
# Saved results for geometry 23244/77493
# Saved results for geometry 23245/77493
# Saved results for geometry 23246/77493
# Saved results for geometry 23247/77493
# Saved results for geometry 23248/77493
# Saved results for geometry 23249/77493
# Saved results for geometry 23250/77493
# Saved results for geometry 23251/77493
# Saved results for geometry 23252/77493
# Saved results for geometry 23253/77493
# Saved results for geometry 23254/77493
# Saved results for geometry 23255/77493
# Saved results for geometry 23256/77493
# Saved results for geometry 23257/77493
# Saved results for geometry 23258/77493
# Saved results for geometry 23259/77493
# Saved results for geometry 23260/77493
# Saved results for geometry 23261/77493
# Saved results for geometry 23262/77493
# Saved results for geometry 23263/77493
# Saved results for geometry 23264/77493
# Saved results for geometry 23265/77493
# Saved results for geometry 23266/77493
# Saved results for geometry 23267/77493
# Saved results for geometry 23268/77493
# Saved results for geometry 23269/77493
# Saved results for geometry 23270/77493
# Saved results for geometry 23271/77493
# Saved results for geometry 23272/77493
# Saved results for geometry 23273/77493
# Saved results for geometry 23274/77493
# Saved results for geometry 23275/77493
# Saved results for geometry 23276/77493
# Saved results for geometry 23277/77493
# Saved results for geometry 23278/77493
# Saved results for geometry 23279/77493
# Saved results for geometry 23280/77493
# Saved results for geometry 23281/77493
# Saved results for geometry 23282/77493
# Saved results for geometry 23283/77493
# Saved results for geometry 23284/77493
# Saved results for geometry 23285/77493
# Saved results for geometry 23286/77493
# Saved results for geometry 23287/77493
# Saved results for geometry 23288/77493
# Saved results for geometry 23289/77493
# Saved results for geometry 23290/77493
# Saved results for geometry 23291/77493
# Saved results for geometry 23292/77493
# Saved results for geometry 23293/77493
# Saved results for geometry 23294/77493
# Saved results for geometry 23295/77493
# Saved results for geometry 23296/77493
# Saved results for geometry 23297/77493
# Saved results for geometry 23298/77493
# Saved results for geometry 23299/77493
# Saved results for geometry 23300/77493
# Saved results for geometry 23301/77493
# Saved results for geometry 23302/77493
# Saved results for geometry 23303/77493
# Saved results for geometry 23304/77493
# Saved results for geometry 23305/77493
# Saved results for geometry 23306/77493
# Saved results for geometry 23307/77493
# Saved results for geometry 23308/77493
# Saved results for geometry 23309/77493
# Saved results for geometry 23310/77493
# Saved results for geometry 23311/77493
# Saved results for geometry 23312/77493
# Saved results for geometry 23313/77493
# Saved results for geometry 23314/77493
# Saved results for geometry 23315/77493
# Saved results for geometry 23316/77493
# Saved results for geometry 23317/77493
# Saved results for geometry 23318/77493
# Saved results for geometry 23319/77493
# Saved results for geometry 23320/77493
# Saved results for geometry 23321/77493
# Saved results for geometry 23322/77493
# Saved results for geometry 23323/77493
# Saved results for geometry 23324/77493
# Saved results for geometry 23325/77493
# Saved results for geometry 23326/77493
# Saved results for geometry 23327/77493
# Saved results for geometry 23328/77493
# Saved results for geometry 23329/77493
# Saved results for geometry 23330/77493
# Saved results for geometry 23331/77493
# Saved results for geometry 23332/77493
# Saved results for geometry 23333/77493
# Saved results for geometry 23334/77493
# Saved results for geometry 23335/77493
# Saved results for geometry 23336/77493
# Saved results for geometry 23337/77493
# Saved results for geometry 23338/77493
# Saved results for geometry 23339/77493
# Saved results for geometry 23340/77493
# Saved results for geometry 23341/77493
# Saved results for geometry 23342/77493
# Saved results for geometry 23343/77493
# Saved results for geometry 23344/77493
# Saved results for geometry 23345/77493
# Saved results for geometry 23346/77493
# Saved results for geometry 23347/77493
# Saved results for geometry 23348/77493
# Saved results for geometry 23349/77493
# Saved results for geometry 23350/77493
# Saved results for geometry 23351/77493
# Saved results for geometry 23352/77493
# Saved results for geometry 23353/77493
# Saved results for geometry 23354/77493
# Saved results for geometry 23355/77493
# Saved results for geometry 23356/77493
# Saved results for geometry 23357/77493
# Saved results for geometry 23358/77493
# Saved results for geometry 23359/77493
# Saved results for geometry 23360/77493
# Saved results for geometry 23361/77493
# Saved results for geometry 23362/77493
# Saved results for geometry 23363/77493
# Saved results for geometry 23364/77493
# Saved results for geometry 23365/77493
# Saved results for geometry 23366/77493
# Saved results for geometry 23367/77493
# Saved results for geometry 23368/77493
# Saved results for geometry 23369/77493
# Saved results for geometry 23370/77493
# Saved results for geometry 23371/77493
# Saved results for geometry 23372/77493
# Saved results for geometry 23373/77493
# Saved results for geometry 23374/77493
# Saved results for geometry 23375/77493
# Saved results for geometry 23376/77493
# Saved results for geometry 23377/77493
# Saved results for geometry 23378/77493
# Saved results for geometry 23379/77493
# Saved results for geometry 23380/77493
# Saved results for geometry 23381/77493
# Saved results for geometry 23382/77493
# Saved results for geometry 23383/77493
# Saved results for geometry 23384/77493
# Saved results for geometry 23385/77493
# Saved results for geometry 23386/77493
# Saved results for geometry 23387/77493
# Saved results for geometry 23388/77493
# Saved results for geometry 23389/77493
# Saved results for geometry 23390/77493
# Saved results for geometry 23391/77493
# Saved results for geometry 23392/77493
# Saved results for geometry 23393/77493
# Saved results for geometry 23394/77493
# Saved results for geometry 23395/77493
# Saved results for geometry 23396/77493
# Saved results for geometry 23397/77493
# Saved results for geometry 23398/77493
# Saved results for geometry 23399/77493
# Saved results for geometry 23400/77493
# Saved results for geometry 23401/77493
# Saved results for geometry 23402/77493
# Saved results for geometry 23403/77493
# Saved results for geometry 23404/77493
# Saved results for geometry 23405/77493
# Saved results for geometry 23406/77493
# Saved results for geometry 23407/77493
# Saved results for geometry 23408/77493
# Saved results for geometry 23409/77493
# Saved results for geometry 23410/77493
# Saved results for geometry 23411/77493
# Saved results for geometry 23412/77493
# Saved results for geometry 23413/77493
# Saved results for geometry 23414/77493
# Saved results for geometry 23415/77493
# Saved results for geometry 23416/77493
# Saved results for geometry 23417/77493
# Saved results for geometry 23418/77493
# Saved results for geometry 23419/77493
# Saved results for geometry 23420/77493
# Saved results for geometry 23421/77493
# Saved results for geometry 23422/77493
# Saved results for geometry 23423/77493
# Saved results for geometry 23424/77493
# Saved results for geometry 23425/77493
# Saved results for geometry 23426/77493
# Saved results for geometry 23427/77493
# Saved results for geometry 23428/77493
# Saved results for geometry 23429/77493
# Saved results for geometry 23430/77493
# Saved results for geometry 23431/77493
# Saved results for geometry 23432/77493
# Saved results for geometry 23433/77493
# Saved results for geometry 23434/77493
# Saved results for geometry 23435/77493
# Saved results for geometry 23436/77493
# Saved results for geometry 23437/77493
# Saved results for geometry 23438/77493
# Saved results for geometry 23439/77493
# No data retrieved for geometry 23440
# Saved results for geometry 23441/77493
# Saved results for geometry 23442/77493
# Saved results for geometry 23443/77493
# Saved results for geometry 23444/77493
# Saved results for geometry 23445/77493
# Saved results for geometry 23446/77493
# Saved results for geometry 23447/77493
# Saved results for geometry 23448/77493
# Saved results for geometry 23449/77493
# Saved results for geometry 23450/77493
# Saved results for geometry 23451/77493
# Saved results for geometry 23452/77493
# Saved results for geometry 23453/77493
# Saved results for geometry 23454/77493
# Saved results for geometry 23455/77493
# Saved results for geometry 23456/77493
# Saved results for geometry 23457/77493
# Saved results for geometry 23458/77493
# Saved results for geometry 23459/77493
# Saved results for geometry 23460/77493
# Saved results for geometry 23461/77493
# Saved results for geometry 23462/77493
# Saved results for geometry 23463/77493
# Saved results for geometry 23464/77493
# Saved results for geometry 23465/77493
# Saved results for geometry 23466/77493
# Saved results for geometry 23467/77493
# Saved results for geometry 23468/77493
# Saved results for geometry 23469/77493
# Saved results for geometry 23470/77493
# Saved results for geometry 23471/77493
# Saved results for geometry 23472/77493
# Saved results for geometry 23473/77493
# Saved results for geometry 23474/77493
# Saved results for geometry 23475/77493
# Saved results for geometry 23476/77493
# Saved results for geometry 23477/77493
# Saved results for geometry 23478/77493
# Saved results for geometry 23479/77493
# Saved results for geometry 23480/77493
# Saved results for geometry 23481/77493
# Saved results for geometry 23482/77493
# Saved results for geometry 23483/77493
# Saved results for geometry 23484/77493
# Saved results for geometry 23485/77493
# Saved results for geometry 23486/77493
# Saved results for geometry 23487/77493
# Saved results for geometry 23488/77493
# Saved results for geometry 23489/77493
# Saved results for geometry 23490/77493
# Saved results for geometry 23491/77493
# Saved results for geometry 23492/77493
# Saved results for geometry 23493/77493
# Saved results for geometry 23494/77493
# Saved results for geometry 23495/77493
# Saved results for geometry 23496/77493
# Saved results for geometry 23497/77493
# Saved results for geometry 23498/77493
# Saved results for geometry 23499/77493
# Saved results for geometry 23500/77493
# Saved results for geometry 23501/77493
# Saved results for geometry 23502/77493
# Saved results for geometry 23503/77493
# Saved results for geometry 23504/77493
# Saved results for geometry 23505/77493
# Saved results for geometry 23506/77493
# Saved results for geometry 23507/77493
# Saved results for geometry 23508/77493
# Saved results for geometry 23509/77493
# Saved results for geometry 23510/77493
# Saved results for geometry 23511/77493
# Saved results for geometry 23512/77493
# Saved results for geometry 23513/77493
# Saved results for geometry 23514/77493
# Saved results for geometry 23515/77493
# Saved results for geometry 23516/77493
# Saved results for geometry 23517/77493
# Saved results for geometry 23518/77493
# Saved results for geometry 23519/77493
# Saved results for geometry 23520/77493
# Saved results for geometry 23521/77493
# Saved results for geometry 23522/77493
# Saved results for geometry 23523/77493
# Saved results for geometry 23524/77493
# Saved results for geometry 23525/77493
# Saved results for geometry 23526/77493
# Saved results for geometry 23527/77493
# Saved results for geometry 23528/77493
# Saved results for geometry 23529/77493
# Saved results for geometry 23530/77493
# Saved results for geometry 23531/77493
# Saved results for geometry 23532/77493
# Saved results for geometry 23533/77493
# Saved results for geometry 23534/77493
# Saved results for geometry 23535/77493
# Saved results for geometry 23536/77493
# Saved results for geometry 23537/77493
# Saved results for geometry 23538/77493
# Saved results for geometry 23539/77493
# Saved results for geometry 23540/77493
# Saved results for geometry 23541/77493
# Saved results for geometry 23542/77493
# Saved results for geometry 23543/77493
# Saved results for geometry 23544/77493
# Saved results for geometry 23545/77493
# Saved results for geometry 23546/77493
# Saved results for geometry 23547/77493
# Saved results for geometry 23548/77493
# Saved results for geometry 23549/77493
# Saved results for geometry 23550/77493
# Saved results for geometry 23551/77493
# Saved results for geometry 23552/77493
# Saved results for geometry 23553/77493
# Saved results for geometry 23554/77493
# Saved results for geometry 23555/77493
# Saved results for geometry 23556/77493
# Saved results for geometry 23557/77493
# Saved results for geometry 23558/77493
# Saved results for geometry 23559/77493
# Saved results for geometry 23560/77493
# Saved results for geometry 23561/77493
# Saved results for geometry 23562/77493
# Saved results for geometry 23563/77493
# Saved results for geometry 23564/77493
# Saved results for geometry 23565/77493
# Saved results for geometry 23566/77493
# Saved results for geometry 23567/77493
# Saved results for geometry 23568/77493
# Saved results for geometry 23569/77493
# Saved results for geometry 23570/77493
# Saved results for geometry 23571/77493
# Saved results for geometry 23572/77493
# Saved results for geometry 23573/77493
# Saved results for geometry 23574/77493
# Saved results for geometry 23575/77493
# Saved results for geometry 23576/77493
# Saved results for geometry 23577/77493
# Saved results for geometry 23578/77493
# Saved results for geometry 23579/77493
# Saved results for geometry 23580/77493
# Saved results for geometry 23581/77493
# Saved results for geometry 23582/77493
# Saved results for geometry 23583/77493
# Saved results for geometry 23584/77493
# Saved results for geometry 23585/77493
# Saved results for geometry 23586/77493
# Saved results for geometry 23587/77493
# Saved results for geometry 23588/77493
# Saved results for geometry 23589/77493
# Saved results for geometry 23590/77493
# Saved results for geometry 23591/77493
# Saved results for geometry 23592/77493
# Saved results for geometry 23593/77493
# Saved results for geometry 23594/77493
# Saved results for geometry 23595/77493
# Saved results for geometry 23596/77493
# Saved results for geometry 23597/77493
# Saved results for geometry 23598/77493
# Saved results for geometry 23599/77493
# Saved results for geometry 23600/77493
# Saved results for geometry 23601/77493
# Saved results for geometry 23602/77493
# Saved results for geometry 23603/77493
# Saved results for geometry 23604/77493
# Saved results for geometry 23605/77493
# Saved results for geometry 23606/77493
# Saved results for geometry 23607/77493
# Saved results for geometry 23608/77493
# Saved results for geometry 23609/77493
# Saved results for geometry 23610/77493
# Saved results for geometry 23611/77493
# Saved results for geometry 23612/77493
# Saved results for geometry 23613/77493
# Saved results for geometry 23614/77493
# Saved results for geometry 23615/77493
# Saved results for geometry 23616/77493
# Saved results for geometry 23617/77493
# Saved results for geometry 23618/77493
# Saved results for geometry 23619/77493
# Saved results for geometry 23620/77493
# Saved results for geometry 23621/77493
# Saved results for geometry 23622/77493
# Saved results for geometry 23623/77493
# Saved results for geometry 23624/77493
# Saved results for geometry 23625/77493
# Saved results for geometry 23626/77493
# Saved results for geometry 23627/77493
# Saved results for geometry 23628/77493
# Saved results for geometry 23629/77493
# Saved results for geometry 23630/77493
# Saved results for geometry 23631/77493
# Saved results for geometry 23632/77493
# Saved results for geometry 23633/77493
# Saved results for geometry 23634/77493
# Saved results for geometry 23635/77493
# Saved results for geometry 23636/77493
# Saved results for geometry 23637/77493
# Saved results for geometry 23638/77493
# Saved results for geometry 23639/77493
# Saved results for geometry 23640/77493
# Saved results for geometry 23641/77493
# Saved results for geometry 23642/77493
# Saved results for geometry 23643/77493
# Saved results for geometry 23644/77493
# Saved results for geometry 23645/77493
# Saved results for geometry 23646/77493
# Saved results for geometry 23647/77493
# Saved results for geometry 23648/77493
# Saved results for geometry 23649/77493
# Saved results for geometry 23650/77493
# Saved results for geometry 23651/77493
# Saved results for geometry 23652/77493
# Saved results for geometry 23653/77493
# Saved results for geometry 23654/77493
# Saved results for geometry 23655/77493
# Saved results for geometry 23656/77493
# Saved results for geometry 23657/77493
# Saved results for geometry 23658/77493
# Saved results for geometry 23659/77493
# Saved results for geometry 23660/77493
# Saved results for geometry 23661/77493
# Saved results for geometry 23662/77493
# Saved results for geometry 23663/77493
# Saved results for geometry 23664/77493
# Saved results for geometry 23665/77493
# Saved results for geometry 23666/77493
# Saved results for geometry 23667/77493
# Saved results for geometry 23668/77493
# Saved results for geometry 23669/77493
# Saved results for geometry 23670/77493
# Saved results for geometry 23671/77493
# Saved results for geometry 23672/77493
# Saved results for geometry 23673/77493
# Saved results for geometry 23674/77493
# Saved results for geometry 23675/77493
# Saved results for geometry 23676/77493
# Saved results for geometry 23677/77493
# Saved results for geometry 23678/77493
# Saved results for geometry 23679/77493
# Saved results for geometry 23680/77493
# Saved results for geometry 23681/77493
# Saved results for geometry 23682/77493
# Saved results for geometry 23683/77493
# Saved results for geometry 23684/77493
# Saved results for geometry 23685/77493
# Saved results for geometry 23686/77493
# Saved results for geometry 23687/77493
# Saved results for geometry 23688/77493
# Saved results for geometry 23689/77493
# Saved results for geometry 23690/77493
# Saved results for geometry 23691/77493
# Saved results for geometry 23692/77493
# Saved results for geometry 23693/77493
# Saved results for geometry 23694/77493
# Saved results for geometry 23695/77493
# Saved results for geometry 23696/77493
# Saved results for geometry 23697/77493
# Saved results for geometry 23698/77493
# Saved results for geometry 23699/77493
# Saved results for geometry 23700/77493
# Saved results for geometry 23701/77493
# Saved results for geometry 23702/77493
# Saved results for geometry 23703/77493
# Saved results for geometry 23704/77493
# Saved results for geometry 23705/77493
# Saved results for geometry 23706/77493
# Saved results for geometry 23707/77493
# Saved results for geometry 23708/77493
# Saved results for geometry 23709/77493
# Saved results for geometry 23710/77493
# Saved results for geometry 23711/77493
# Saved results for geometry 23712/77493
# Saved results for geometry 23713/77493
# Saved results for geometry 23714/77493
# Saved results for geometry 23715/77493
# Saved results for geometry 23716/77493
# Saved results for geometry 23717/77493
# Saved results for geometry 23718/77493
# Saved results for geometry 23719/77493
# Saved results for geometry 23720/77493
# Saved results for geometry 23721/77493
# Saved results for geometry 23722/77493
# Saved results for geometry 23723/77493
# Saved results for geometry 23724/77493
# Saved results for geometry 23725/77493
# Saved results for geometry 23726/77493
# Saved results for geometry 23727/77493
# Saved results for geometry 23728/77493
# Saved results for geometry 23729/77493
# Saved results for geometry 23730/77493
# Saved results for geometry 23731/77493
# Saved results for geometry 23732/77493
# Saved results for geometry 23733/77493
# Saved results for geometry 23734/77493
# Saved results for geometry 23735/77493
# Saved results for geometry 23736/77493
# Saved results for geometry 23737/77493
# ...
# No data retrieved for geometry 99590
# Saved results for geometry 99591/77493
# Saved results for geometry 99592/77493
# Saved results for geometry 99593/77493
# Saved results for geometry 99594/77493
# Saved results for geometry 99595/77493
# Saved results for geometry 99596/77493
# Saved results for geometry 99597/77493
# Saved results for geometry 99598/77493
# Saved results for geometry 99599/77493
# Saved results for geometry 99600/77493
# Saved results for geometry 99601/77493
# Saved results for geometry 99602/77493
# Saved results for geometry 99603/77493
# Saved results for geometry 99604/77493
# Saved results for geometry 99605/77493
# Saved results for geometry 99606/77493
# Saved results for geometry 99607/77493
# Saved results for geometry 99608/77493
# Saved results for geometry 99609/77493
# Saved results for geometry 99610/77493
# Saved results for geometry 99611/77493
# Saved results for geometry 99612/77493
# Saved results for geometry 99613/77493
# Saved results for geometry 99614/77493
# Saved results for geometry 99615/77493
# Saved results for geometry 99616/77493
# Saved results for geometry 99617/77493
# Saved results for geometry 99618/77493
# Saved results for geometry 99619/77493
# Saved results for geometry 99620/77493
# Saved results for geometry 99621/77493
# Saved results for geometry 99622/77493
# Saved results for geometry 99623/77493
# Saved results for geometry 99624/77493
# Saved results for geometry 99625/77493
# Saved results for geometry 99626/77493
# Saved results for geometry 99627/77493
# Saved results for geometry 99628/77493
# Saved results for geometry 99629/77493
# Saved results for geometry 99630/77493
# Saved results for geometry 99631/77493
# Saved results for geometry 99632/77493
# Saved results for geometry 99633/77493
# Saved results for geometry 99634/77493
# Saved results for geometry 99635/77493
# Saved results for geometry 99636/77493
# No data retrieved for geometry 99637
# Saved results for geometry 99638/77493
# Saved results for geometry 99639/77493
# Saved results for geometry 99640/77493
# Saved results for geometry 99641/77493
# Saved results for geometry 99642/77493
# Saved results for geometry 99643/77493
# Saved results for geometry 99644/77493
# Saved results for geometry 99645/77493
# Saved results for geometry 99646/77493
# Saved results for geometry 99647/77493
# Saved results for geometry 99648/77493
# Saved results for geometry 99649/77493
# Saved results for geometry 99650/77493
# Saved results for geometry 99651/77493
# Saved results for geometry 99652/77493
# Saved results for geometry 99653/77493
# Saved results for geometry 99654/77493
# Saved results for geometry 99655/77493
# Saved results for geometry 99656/77493
# Saved results for geometry 99657/77493
# Saved results for geometry 99658/77493
# Saved results for geometry 99659/77493
# Saved results for geometry 99660/77493
# Saved results for geometry 99661/77493
# Saved results for geometry 99662/77493
# Saved results for geometry 99663/77493
# Saved results for geometry 99664/77493
# Saved results for geometry 99665/77493
# Saved results for geometry 99666/77493
# Saved results for geometry 99667/77493
# Saved results for geometry 99668/77493
# Saved results for geometry 99669/77493
# Saved results for geometry 99670/77493
# Saved results for geometry 99671/77493
# Saved results for geometry 99672/77493
# Saved results for geometry 99673/77493
# Saved results for geometry 99674/77493
# Saved results for geometry 99675/77493
# Saved results for geometry 99676/77493
# Saved results for geometry 99677/77493
# Saved results for geometry 99678/77493
# Saved results for geometry 99679/77493
# Saved results for geometry 99680/77493
# Saved results for geometry 99681/77493
# Saved results for geometry 99682/77493
# Saved results for geometry 99683/77493
# Saved results for geometry 99684/77493
# Saved results for geometry 99685/77493
# Saved results for geometry 99686/77493
# Saved results for geometry 99687/77493
# Saved results for geometry 99688/77493
# Saved results for geometry 99689/77493
# Saved results for geometry 99690/77493
# Saved results for geometry 99691/77493
# Saved results for geometry 99692/77493
# Saved results for geometry 99693/77493
# Saved results for geometry 99694/77493
# Saved results for geometry 99695/77493
# Saved results for geometry 99696/77493
# Saved results for geometry 99697/77493
# Saved results for geometry 99698/77493
# Saved results for geometry 99699/77493
# Saved results for geometry 99700/77493
# Saved results for geometry 99701/77493
# Saved results for geometry 99702/77493
# Saved results for geometry 99703/77493
# Saved results for geometry 99704/77493
# Saved results for geometry 99705/77493
# Saved results for geometry 99706/77493
# Saved results for geometry 99707/77493
# Saved results for geometry 99708/77493
# Saved results for geometry 99709/77493
# Saved results for geometry 99710/77493
# Saved results for geometry 99711/77493
# Saved results for geometry 99712/77493
# No data retrieved for geometry 99713
# Saved results for geometry 99714/77493
# Saved results for geometry 99715/77493
# Saved results for geometry 99716/77493
# Saved results for geometry 99717/77493
# Saved results for geometry 99718/77493
# Saved results for geometry 99719/77493
# Saved results for geometry 99720/77493
# Saved results for geometry 99721/77493
# Saved results for geometry 99722/77493
# Saved results for geometry 99723/77493
# No data retrieved for geometry 99724
# Saved results for geometry 99725/77493
# Saved results for geometry 99726/77493
# Saved results for geometry 99727/77493
# Saved results for geometry 99728/77493
# Saved results for geometry 99729/77493
# Saved results for geometry 99730/77493
# Saved results for geometry 99731/77493
# Saved results for geometry 99732/77493
# Saved results for geometry 99733/77493
# Saved results for geometry 99734/77493
# Saved results for geometry 99735/77493
# Saved results for geometry 99736/77493
# Saved results for geometry 99737/77493
# Saved results for geometry 99738/77493
# Saved results for geometry 99739/77493
# Saved results for geometry 99740/77493
# Saved results for geometry 99741/77493
# Saved results for geometry 99742/77493
# Saved results for geometry 99743/77493
# Saved results for geometry 99744/77493
# Saved results for geometry 99745/77493
# Saved results for geometry 99746/77493
# Saved results for geometry 99747/77493
# Saved results for geometry 99748/77493
# Saved results for geometry 99749/77493
# Saved results for geometry 99750/77493
# Saved results for geometry 99751/77493
# Saved results for geometry 99752/77493
# Saved results for geometry 99753/77493
# Saved results for geometry 99754/77493
# Saved results for geometry 99755/77493
# Saved results for geometry 99756/77493
# Saved results for geometry 99757/77493
# Saved results for geometry 99758/77493
# Saved results for geometry 99759/77493
# Saved results for geometry 99760/77493
# Saved results for geometry 99761/77493
# Saved results for geometry 99762/77493
# Saved results for geometry 99763/77493
# Saved results for geometry 99764/77493
# Saved results for geometry 99765/77493
# Saved results for geometry 99766/77493
# Saved results for geometry 99767/77493
# Saved results for geometry 99768/77493
# Saved results for geometry 99769/77493
# Saved results for geometry 99770/77493
# Saved results for geometry 99771/77493
# Saved results for geometry 99772/77493
# Saved results for geometry 99773/77493
# Saved results for geometry 99774/77493
# Saved results for geometry 99775/77493
# Saved results for geometry 99776/77493
# Saved results for geometry 99777/77493
# Saved results for geometry 99778/77493
# Saved results for geometry 99779/77493
# Saved results for geometry 99780/77493
# Saved results for geometry 99781/77493
# Saved results for geometry 99782/77493
# Saved results for geometry 99783/77493
# Saved results for geometry 99784/77493
# No data retrieved for geometry 99785
# Saved results for geometry 99786/77493
# Saved results for geometry 99787/77493
# Saved results for geometry 99788/77493
# Saved results for geometry 99789/77493
# Saved results for geometry 99790/77493
# Saved results for geometry 99791/77493
# Saved results for geometry 99792/77493
# Saved results for geometry 99793/77493
# Saved results for geometry 99794/77493
# Saved results for geometry 99795/77493
# Saved results for geometry 99796/77493
# Saved results for geometry 99797/77493
# Saved results for geometry 99798/77493
# Saved results for geometry 99799/77493
# Saved results for geometry 99800/77493
# Saved results for geometry 99801/77493
# Saved results for geometry 99802/77493
# Saved results for geometry 99803/77493
# Saved results for geometry 99804/77493
# Saved results for geometry 99805/77493
# Saved results for geometry 99806/77493
# Saved results for geometry 99807/77493
# Saved results for geometry 99808/77493
# Saved results for geometry 99809/77493
# Saved results for geometry 99810/77493
# Saved results for geometry 99811/77493
# Saved results for geometry 99812/77493
# Saved results for geometry 99813/77493
# Saved results for geometry 99814/77493
# Saved results for geometry 99815/77493
# Saved results for geometry 99816/77493
# Saved results for geometry 99817/77493
# Saved results for geometry 99818/77493
# Saved results for geometry 99819/77493
# Saved results for geometry 99820/77493
# Saved results for geometry 99821/77493
# Saved results for geometry 99822/77493
# Saved results for geometry 99823/77493
# Saved results for geometry 99824/77493
# Saved results for geometry 99825/77493
# Saved results for geometry 99826/77493
# Saved results for geometry 99827/77493
# Saved results for geometry 99828/77493
# Saved results for geometry 99829/77493
# Saved results for geometry 99830/77493
# Saved results for geometry 99831/77493
# Saved results for geometry 99832/77493
# Saved results for geometry 99833/77493
# Saved results for geometry 99834/77493
# Saved results for geometry 99835/77493
# Saved results for geometry 99836/77493
# Saved results for geometry 99837/77493
# Saved results for geometry 99838/77493
# Saved results for geometry 99839/77493
# Saved results for geometry 99840/77493
# Saved results for geometry 99841/77493
# Saved results for geometry 99842/77493
# Saved results for geometry 99843/77493
# Saved results for geometry 99844/77493
# Saved results for geometry 99845/77493
# Saved results for geometry 99846/77493
# Saved results for geometry 99847/77493
# Saved results for geometry 99848/77493
# Saved results for geometry 99849/77493
# Saved results for geometry 99850/77493
# Saved results for geometry 99851/77493
# Saved results for geometry 99852/77493
# Saved results for geometry 99853/77493
# Saved results for geometry 99854/77493
# Saved results for geometry 99855/77493
# Saved results for geometry 99856/77493
# Saved results for geometry 99857/77493
# Saved results for geometry 99858/77493
# Saved results for geometry 99859/77493
# Saved results for geometry 99860/77493
# Saved results for geometry 99861/77493
# Saved results for geometry 99862/77493
# Saved results for geometry 99863/77493
# Saved results for geometry 99864/77493
# Saved results for geometry 99865/77493
# Saved results for geometry 99866/77493
# Saved results for geometry 99867/77493
# Saved results for geometry 99868/77493
# Saved results for geometry 99869/77493
# Saved results for geometry 99870/77493
# Saved results for geometry 99871/77493
# Saved results for geometry 99872/77493
# Saved results for geometry 99873/77493
# Saved results for geometry 99874/77493
# Saved results for geometry 99875/77493
# Saved results for geometry 99876/77493
# Saved results for geometry 99877/77493
# Saved results for geometry 99878/77493
# Saved results for geometry 99879/77493
# No data retrieved for geometry 99880
# Saved results for geometry 99881/77493
# Saved results for geometry 99882/77493
# Saved results for geometry 99883/77493
# Saved results for geometry 99884/77493
# Saved results for geometry 99885/77493
# Saved results for geometry 99886/77493
# Saved results for geometry 99887/77493
# Saved results for geometry 99888/77493
# Saved results for geometry 99889/77493
# Saved results for geometry 99890/77493
# Saved results for geometry 99891/77493
# Saved results for geometry 99892/77493
# Saved results for geometry 99893/77493
# Saved results for geometry 99894/77493
# Saved results for geometry 99895/77493
# Saved results for geometry 99896/77493
# Saved results for geometry 99897/77493
# Saved results for geometry 99898/77493
# Saved results for geometry 99899/77493
# Saved results for geometry 99900/77493
# Saved results for geometry 99901/77493
# Saved results for geometry 99902/77493
# Saved results for geometry 99903/77493
# Saved results for geometry 99904/77493
# Saved results for geometry 99905/77493
# Saved results for geometry 99906/77493
# Saved results for geometry 99907/77493
# Saved results for geometry 99908/77493
# Saved results for geometry 99909/77493
# Saved results for geometry 99910/77493
# Saved results for geometry 99911/77493
# Saved results for geometry 99912/77493
# Saved results for geometry 99913/77493
# Saved results for geometry 99914/77493
# Saved results for geometry 99915/77493
# Saved results for geometry 99916/77493
# Saved results for geometry 99917/77493
# Saved results for geometry 99918/77493
# Saved results for geometry 99919/77493
# Saved results for geometry 99920/77493
# Saved results for geometry 99921/77493
# Saved results for geometry 99922/77493
# Saved results for geometry 99923/77493
# Saved results for geometry 99924/77493
# No data retrieved for geometry 99925
# Saved results for geometry 99926/77493
# No data retrieved for geometry 99927
# Saved results for geometry 99928/77493
# Saved results for geometry 99929/77493
# Saved results for geometry 99930/77493
# Saved results for geometry 99931/77493
# Saved results for geometry 99932/77493
# Saved results for geometry 99933/77493
# Saved results for geometry 99934/77493
# Saved results for geometry 99935/77493
# Saved results for geometry 99936/77493
# Saved results for geometry 99937/77493
# Saved results for geometry 99938/77493
# Saved results for geometry 99939/77493
# Saved results for geometry 99940/77493
# Saved results for geometry 99941/77493
# Saved results for geometry 99942/77493
# Saved results for geometry 99943/77493
# Saved results for geometry 99944/77493
# Saved results for geometry 99945/77493
# Saved results for geometry 99946/77493
# Saved results for geometry 99947/77493
# Saved results for geometry 99948/77493
# Saved results for geometry 99949/77493
# Saved results for geometry 99950/77493
# Saved results for geometry 99951/77493
# Saved results for geometry 99952/77493
# Saved results for geometry 99953/77493
# Saved results for geometry 99954/77493
# Saved results for geometry 99955/77493
# Saved results for geometry 99956/77493
# Saved results for geometry 99957/77493
# Saved results for geometry 99958/77493
# Saved results for geometry 99959/77493
# Saved results for geometry 99960/77493
# Saved results for geometry 99961/77493
# Saved results for geometry 99962/77493
# Saved results for geometry 99963/77493
# Saved results for geometry 99964/77493
# Saved results for geometry 99965/77493
# Saved results for geometry 99966/77493
# Saved results for geometry 99967/77493
# Saved results for geometry 99968/77493
# Saved results for geometry 99969/77493
# Saved results for geometry 99970/77493
# Saved results for geometry 99971/77493
# Saved results for geometry 99972/77493
# Saved results for geometry 99973/77493
# Saved results for geometry 99974/77493
# Saved results for geometry 99975/77493
# Saved results for geometry 99976/77493
# Saved results for geometry 99977/77493
# Saved results for geometry 99978/77493
# Saved results for geometry 99979/77493
# Saved results for geometry 99980/77493
# Saved results for geometry 99981/77493
# Saved results for geometry 99982/77493
# Saved results for geometry 99983/77493
# Saved results for geometry 99984/77493
# Saved results for geometry 99985/77493
# Saved results for geometry 99986/77493
# Saved results for geometry 99987/77493
# Saved results for geometry 99988/77493
# Saved results for geometry 99989/77493
# Saved results for geometry 99990/77493
# Saved results for geometry 99991/77493
# Saved results for geometry 99992/77493
# Saved results for geometry 99993/77493
# Saved results for geometry 99994/77493
# Saved results for geometry 99995/77493
# Saved results for geometry 99996/77493
# Saved results for geometry 99997/77493
# Saved results for geometry 99998/77493
# Saved results for geometry 99999/77493
