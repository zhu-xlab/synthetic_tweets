# %%
import json
import pandas as pd
import os
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import shape, Polygon, MultiPolygon
from shapely.wkt import loads
import requests

# %%
print(os.getpid())
# Out:
# 22093

# %%
df = pd.read_csv("/mntssd/mnt3/shanshanbai/nlpinearthobservation/synthetic_data/merged.csv", sep=",")

df['geometry'] = df['geometry'].apply(loads)

# %%
# Output JSON Lines file to save results dynamically
output_file = "/mntssd/mnt3/shanshanbai/my_storage_from_qian/results/allnew.jsonl"

# %%
# Define Overpass API endpoint
url = "https://overpass-api.de/api/interpreter"

# %%
# Function to decode Unicode escape sequences
def decode_unicode(string):
    try:
        return json.loads(f'"{string}"')  # Decodes strings like "\u00fc" to "ü"
    except json.JSONDecodeError:
        return string  # Return the string as-is if decoding fails

# Function to extract building information
def extract_building_info(element):
    tags = element.get('tags', {})
    building_type = tags.get('building')
    name = tags.get('name')
    operator = tags.get('operator')

    # Decode Unicode sequences in strings
    if name:
        name = decode_unicode(name)
    if operator:
        operator = decode_unicode(operator)
    
    return building_type, name, operator

# %%
# Process each geometry in the DataFrame
for index, row in df.iterrows():
    geometry = row['geometry']
    bounds = geometry.bounds  # (minx, miny, maxx, maxy)
    south, west, north, east = bounds[1], bounds[0], bounds[3], bounds[2]

    # Overpass query to retrieve relations, ways, and nodes
    query = f"""
    [out:json];
    (
      way["building"]({south},{west},{north},{east});
      relation["building"]({south},{west},{north},{east});
      node["building"]({south},{west},{north},{east});
    );
    out body;
    >;
    out skel qt;
    """
    
    # Initialize combined data for the current geometry
    combined_data = {
        'index': index,
        'building id': row.get("osm_building_id", None),
        'building class': row.get("building_class", None),
        'building city': row.get("building_city", None),
        'building tags': set(),
        'building names': set(),
        'building operators': set(),
        'tweet language distribution': row.get("tweet_lang", None),  # Include additional column if available
        'error': None  # Track errors if they occur
    }

    # Query the Overpass API
    try:
        response = requests.get(url, params={"data": query})
        response.raise_for_status()
        data = response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error querying Overpass API for geometry {index}: {e}")
        combined_data['error'] = f"HTTP error: {str(e)}"
        # Write the error result for this row
        with open(output_file, "a", encoding="utf-8") as f:
            json.dump(combined_data, f, ensure_ascii=False)
            f.write("\n")
        continue  # Skip processing this row

    # Check if data is empty
    if not data.get("elements"):
        print(f"No data retrieved for geometry {index}")
        combined_data['error'] = "No data retrieved from Overpass API"
        # Write the empty result for this row
        with open(output_file, "a", encoding="utf-8") as f:
            json.dump(combined_data, f, ensure_ascii=False)
            f.write("\n")
        continue

    # Process elements from the response
    for element in data.get("elements", []):
        if element["type"] in ["relation", "way"]:
            building_type, name, operator = extract_building_info(element)
            if building_type and building_type != "yes":
                combined_data["building tags"].add(building_type)
            if name:
                combined_data["building names"].add(name)
            if operator:
                combined_data["building operators"].add(operator)

    # Convert sets to lists for JSON compatibility
    combined_data["building tags"] = list(combined_data["building tags"])
    combined_data["building names"] = list(combined_data["building names"])
    combined_data["building operators"] = list(combined_data["building operators"])

    # Use fallback from 'building_class' if 'building tags' is empty
    if not combined_data['building tags']:
        fallback_class = row.get("building_class", None)
        if pd.notna(fallback_class):
            combined_data['building tags'].append(fallback_class)

    # Save results dynamically to JSON Lines file
    with open(output_file, "a", encoding="utf-8") as f:
        json.dump(combined_data, f, ensure_ascii=False)
        f.write("\n")

    print(f"Saved results for geometry {index}/{len(df)}")
# Out:
# Saved results for geometry 0/655425
# Saved results for geometry 1/655425
# Saved results for geometry 2/655425
# Saved results for geometry 3/655425
# Saved results for geometry 4/655425
# Saved results for geometry 5/655425
# Saved results for geometry 6/655425
# Saved results for geometry 7/655425
# Saved results for geometry 8/655425
# Saved results for geometry 9/655425
# Saved results for geometry 10/655425
# Saved results for geometry 11/655425
# Saved results for geometry 12/655425
# Saved results for geometry 13/655425
# Saved results for geometry 14/655425
# Saved results for geometry 15/655425
# Saved results for geometry 16/655425
# Saved results for geometry 17/655425
# Saved results for geometry 18/655425
# Saved results for geometry 19/655425
# Saved results for geometry 20/655425
# Saved results for geometry 21/655425
# Saved results for geometry 22/655425
# Saved results for geometry 23/655425
# Saved results for geometry 24/655425
# Saved results for geometry 25/655425
# Saved results for geometry 26/655425
# Saved results for geometry 27/655425
# Saved results for geometry 28/655425
# Saved results for geometry 29/655425
# Saved results for geometry 30/655425
# Saved results for geometry 31/655425
# Saved results for geometry 32/655425
# Saved results for geometry 33/655425
# Saved results for geometry 34/655425
# Saved results for geometry 35/655425
# Saved results for geometry 36/655425
# Saved results for geometry 37/655425
# Saved results for geometry 38/655425
# Saved results for geometry 39/655425
# Saved results for geometry 40/655425
# Saved results for geometry 41/655425
# Saved results for geometry 42/655425
# Saved results for geometry 43/655425
# Saved results for geometry 44/655425
# Saved results for geometry 45/655425
# Saved results for geometry 46/655425
# Saved results for geometry 47/655425
# Saved results for geometry 48/655425
# Saved results for geometry 49/655425
# Saved results for geometry 50/655425
# Saved results for geometry 51/655425
# Saved results for geometry 52/655425
# Saved results for geometry 53/655425
# Saved results for geometry 54/655425
# Saved results for geometry 55/655425
# Saved results for geometry 56/655425
# Saved results for geometry 57/655425
# Saved results for geometry 58/655425
# Saved results for geometry 59/655425
# Saved results for geometry 60/655425
# Saved results for geometry 61/655425
# Saved results for geometry 62/655425
# Saved results for geometry 63/655425
# Saved results for geometry 64/655425
# Saved results for geometry 65/655425
# Saved results for geometry 66/655425
# Saved results for geometry 67/655425
# Saved results for geometry 68/655425
# Saved results for geometry 69/655425
# Saved results for geometry 70/655425
# Saved results for geometry 71/655425
# Saved results for geometry 72/655425
# Saved results for geometry 73/655425
# Saved results for geometry 74/655425
# Saved results for geometry 75/655425
# Saved results for geometry 76/655425
# Saved results for geometry 77/655425
# Saved results for geometry 78/655425
# Saved results for geometry 79/655425
# Saved results for geometry 80/655425
# Saved results for geometry 81/655425
# Saved results for geometry 82/655425
# Saved results for geometry 83/655425
# Saved results for geometry 84/655425
# Saved results for geometry 85/655425
# Saved results for geometry 86/655425
# Saved results for geometry 87/655425
# Saved results for geometry 88/655425
# Saved results for geometry 89/655425
# Saved results for geometry 90/655425
# Saved results for geometry 91/655425
# Saved results for geometry 92/655425
# Saved results for geometry 93/655425
# Saved results for geometry 94/655425
# Saved results for geometry 95/655425
# Saved results for geometry 96/655425
# Saved results for geometry 97/655425
# Saved results for geometry 98/655425
# Saved results for geometry 99/655425
# Saved results for geometry 100/655425
# Saved results for geometry 101/655425
# Saved results for geometry 102/655425
# Saved results for geometry 103/655425
# Saved results for geometry 104/655425
# Saved results for geometry 105/655425
# Saved results for geometry 106/655425
# Saved results for geometry 107/655425
# Saved results for geometry 108/655425
# Saved results for geometry 109/655425
# Saved results for geometry 110/655425
# Saved results for geometry 111/655425
# Saved results for geometry 112/655425
# Saved results for geometry 113/655425
# Saved results for geometry 114/655425
# Saved results for geometry 115/655425
# Saved results for geometry 116/655425
# Saved results for geometry 117/655425
# Saved results for geometry 118/655425
# Saved results for geometry 119/655425
# Saved results for geometry 120/655425
# Saved results for geometry 121/655425
# Saved results for geometry 122/655425
# Saved results for geometry 123/655425
# Saved results for geometry 124/655425
# Saved results for geometry 125/655425
# Saved results for geometry 126/655425
# Saved results for geometry 127/655425
# Saved results for geometry 128/655425
# Saved results for geometry 129/655425
# Saved results for geometry 130/655425
# Saved results for geometry 131/655425
# Saved results for geometry 132/655425
# Saved results for geometry 133/655425
# Saved results for geometry 134/655425
# Saved results for geometry 135/655425
# Saved results for geometry 136/655425
# Saved results for geometry 137/655425
# Saved results for geometry 138/655425
# Saved results for geometry 139/655425
# Saved results for geometry 140/655425
# Saved results for geometry 141/655425
# Saved results for geometry 142/655425
# Saved results for geometry 143/655425
# Saved results for geometry 144/655425
# Saved results for geometry 145/655425
# Saved results for geometry 146/655425
# Saved results for geometry 147/655425
# Saved results for geometry 148/655425
# Saved results for geometry 149/655425
# Saved results for geometry 150/655425
# Saved results for geometry 151/655425
# Saved results for geometry 152/655425
# Saved results for geometry 153/655425
# Saved results for geometry 154/655425
# Saved results for geometry 155/655425
# Saved results for geometry 156/655425
# Saved results for geometry 157/655425
# Saved results for geometry 158/655425
# Saved results for geometry 159/655425
# Saved results for geometry 160/655425
# Saved results for geometry 161/655425
# Saved results for geometry 162/655425
# Saved results for geometry 163/655425
# Saved results for geometry 164/655425
# Saved results for geometry 165/655425
# Saved results for geometry 166/655425
# Saved results for geometry 167/655425
# Saved results for geometry 168/655425
# Saved results for geometry 169/655425
# Saved results for geometry 170/655425
# Saved results for geometry 171/655425
# Saved results for geometry 172/655425
# Saved results for geometry 173/655425
# Saved results for geometry 174/655425
# Saved results for geometry 175/655425
# Saved results for geometry 176/655425
# Saved results for geometry 177/655425
# Saved results for geometry 178/655425
# Saved results for geometry 179/655425
# Saved results for geometry 180/655425
# Saved results for geometry 181/655425
# Saved results for geometry 182/655425
# Saved results for geometry 183/655425
# Saved results for geometry 184/655425
# Saved results for geometry 185/655425
# Saved results for geometry 186/655425
# Saved results for geometry 187/655425
# Saved results for geometry 188/655425
# Saved results for geometry 189/655425
# Saved results for geometry 190/655425
# Saved results for geometry 191/655425
# Saved results for geometry 192/655425
# Saved results for geometry 193/655425
# Saved results for geometry 194/655425
# Saved results for geometry 195/655425
# Saved results for geometry 196/655425
# Saved results for geometry 197/655425
# Saved results for geometry 198/655425
# Saved results for geometry 199/655425
# Saved results for geometry 200/655425
# Saved results for geometry 201/655425
# Saved results for geometry 202/655425
# Saved results for geometry 203/655425
# Saved results for geometry 204/655425
# Saved results for geometry 205/655425
# Saved results for geometry 206/655425
# Saved results for geometry 207/655425
# Saved results for geometry 208/655425
# Saved results for geometry 209/655425
# Saved results for geometry 210/655425
# Saved results for geometry 211/655425
# Saved results for geometry 212/655425
# Saved results for geometry 213/655425
# Saved results for geometry 214/655425
# Saved results for geometry 215/655425
# Saved results for geometry 216/655425
# Saved results for geometry 217/655425
# Saved results for geometry 218/655425
# Saved results for geometry 219/655425
# Saved results for geometry 220/655425
# Saved results for geometry 221/655425
# Saved results for geometry 222/655425
# Saved results for geometry 223/655425
# Saved results for geometry 224/655425
# Saved results for geometry 225/655425
# Saved results for geometry 226/655425
# Saved results for geometry 227/655425
# Saved results for geometry 228/655425
# Saved results for geometry 229/655425
# Saved results for geometry 230/655425
# Saved results for geometry 231/655425
# Saved results for geometry 232/655425
# Saved results for geometry 233/655425
# Saved results for geometry 234/655425
# Saved results for geometry 235/655425
# Saved results for geometry 236/655425
# Saved results for geometry 237/655425
# Saved results for geometry 238/655425
# Saved results for geometry 239/655425
# Saved results for geometry 240/655425
# Saved results for geometry 241/655425
# Saved results for geometry 242/655425
# Saved results for geometry 243/655425
# Saved results for geometry 244/655425
# Saved results for geometry 245/655425
# Saved results for geometry 246/655425
# Saved results for geometry 247/655425
# Saved results for geometry 248/655425
# Saved results for geometry 249/655425
# Saved results for geometry 250/655425
# Saved results for geometry 251/655425
# Saved results for geometry 252/655425
# Saved results for geometry 253/655425
# Saved results for geometry 254/655425
# Saved results for geometry 255/655425
# Saved results for geometry 256/655425
# Saved results for geometry 257/655425
# Saved results for geometry 258/655425
# Saved results for geometry 259/655425
# Saved results for geometry 260/655425
# Saved results for geometry 261/655425
# Saved results for geometry 262/655425
# Saved results for geometry 263/655425
# Saved results for geometry 264/655425
# Saved results for geometry 265/655425
# Saved results for geometry 266/655425
# Saved results for geometry 267/655425
# Saved results for geometry 268/655425
# Saved results for geometry 269/655425
# Saved results for geometry 270/655425
# Saved results for geometry 271/655425
# Saved results for geometry 272/655425
# Saved results for geometry 273/655425
# Saved results for geometry 274/655425
# Saved results for geometry 275/655425
# Saved results for geometry 276/655425
# Saved results for geometry 277/655425
# Saved results for geometry 278/655425
# Saved results for geometry 279/655425
# Saved results for geometry 280/655425
# Saved results for geometry 281/655425
# Saved results for geometry 282/655425
# Saved results for geometry 283/655425
# Saved results for geometry 284/655425
# Saved results for geometry 285/655425
# Saved results for geometry 286/655425
# Saved results for geometry 287/655425
# Saved results for geometry 288/655425
# Saved results for geometry 289/655425
# Saved results for geometry 290/655425
# Saved results for geometry 291/655425
# Saved results for geometry 292/655425
# Saved results for geometry 293/655425
# Saved results for geometry 294/655425
# Saved results for geometry 295/655425
# Saved results for geometry 296/655425
# Saved results for geometry 297/655425
# Saved results for geometry 298/655425
# Saved results for geometry 299/655425
# Saved results for geometry 300/655425
# Saved results for geometry 301/655425
# Saved results for geometry 302/655425
# Saved results for geometry 303/655425
# Saved results for geometry 304/655425
# Saved results for geometry 305/655425
# Saved results for geometry 306/655425
# Saved results for geometry 307/655425
# Saved results for geometry 308/655425
# Saved results for geometry 309/655425
# Saved results for geometry 310/655425
# Saved results for geometry 311/655425
# Saved results for geometry 312/655425
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 35
#      33 # Query the Overpass API
#      34 try:
# ---> 35     response = requests.get(url, params={"data": query})
#      36     response.raise_for_status()
#      37     data = response.json()
#
# File /usr/local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/local/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File /usr/local/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
